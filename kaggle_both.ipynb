# %% [markdown]
# # Kaggle / Colab Pipeline: TD3 vs DDPG Comparative Suite (12 Distinct Conditions)
#
# This notebook provides **12 independent experiment cells** — exactly one cell per experimental condition.
# Each cell runs its assigned condition across the **3 random seeds (0, 42, 123)** for 2,000 episodes and 600 max steps,
# followed automatically by 20 deterministic evaluation episodes on the best checkpoint.
#
# > **Important Note for Kaggle:** Ensure **Internet Access is enabled** in the notebook settings panel (`Settings -> Internet -> On`) so the repository can be cloned and dependencies installed.

# %% [markdown]
# ## 1. Setup & Workspace Configuration

# %%
import os
import sys
import shutil
from pathlib import Path

# 1. Locate or clone project directory
if Path("run_experiments.py").exists():
    print("Already in repository directory:", os.getcwd())
elif Path("TD3-DDPG-Car-Game/run_experiments.py").exists():
    os.chdir("TD3-DDPG-Car-Game")
    # %cd TD3-DDPG-Car-Game
elif Path("/kaggle/input").exists() and list(Path("/kaggle/input").glob("**/run_experiments.py")):
    src_dir = list(Path("/kaggle/input").glob("**/run_experiments.py"))[0].parent
    print(f"Copying project from {src_dir} to /kaggle/working/TD3-DDPG-Car-Game...")
    # !cp -r "{src_dir}" /kaggle/working/TD3-DDPG-Car-Game
    os.chdir("/kaggle/working/TD3-DDPG-Car-Game")
    # %cd /kaggle/working/TD3-DDPG-Car-Game
else:
    # !git clone https://github.com/adityagangwani30/TD3-DDPG-Car-Game.git
    if Path("TD3-DDPG-Car-Game").exists():
        os.chdir("TD3-DDPG-Car-Game")
        # %cd TD3-DDPG-Car-Game

# 2. Clean any stale symlinks and ensure standard output directories exist
for folder in ["logs_v2", "models_v2", "results_v2"]:
    p = Path(folder)
    if p.is_symlink():
        p.unlink()
    p.mkdir(parents=True, exist_ok=True)

print("Working Directory :", os.getcwd())
print("Output Directories: logs_v2/, models_v2/, results_v2/")

# %% [markdown]
# ## 2. Install Dependencies

# %%
import os
from pathlib import Path

# Ensure directory context before installing requirements
if not Path("requirements.txt").exists() and Path("TD3-DDPG-Car-Game/requirements.txt").exists():
    os.chdir("TD3-DDPG-Car-Game")
    # %cd TD3-DDPG-Car-Game

if Path("requirements.txt").exists():
    # !pip install -r requirements.txt
else:
    print("Installing dependencies directly...")
    # !pip install torch pygame numpy matplotlib reportlab

# %% [markdown]
# ## 3. GPU Hardware & Environment Check

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Hardware Accelerator:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
print("PyTorch Device      :", device)

# %% [markdown]
# ## 4. Pre-Flight Verification Suite (16 Checks)

# %%
# !python preflight_checks.py

# %% [markdown]
# ## 5. Experiment Execution (TD3 + DDPG Comparative Suite — 12 Condition Cells)
#
# Each cell below runs **both TD3 and DDPG for exactly one condition** across seeds **0, 42, 123** (6 runs per cell).
# An intermediate checkpoint cell automatically saves ZIP archives of `logs_v2/` and `models_v2/` after every 3 experiments.

# %% [markdown]
# ### Experiment 01/12: R1_N1 — R1 Basic x N1 (0.00)
# **Reward:** `basic` | **Sensor Noise:** `0.00` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 01/12: R1_N1 (R1 Basic x N1 (0.00))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 0 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 0 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 02/12: R1_N2 — R1 Basic x N2 (0.02)
# **Reward:** `basic` | **Sensor Noise:** `0.02` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 02/12: R1_N2 (R1 Basic x N2 (0.02))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 1 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 1 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 03/12: R1_N3 — R1 Basic x N3 (0.05)
# **Reward:** `basic` | **Sensor Noise:** `0.05` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 03/12: R1_N3 (R1 Basic x N3 (0.05))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 2 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 2 --max-experiments 1 --headless --resume

# %% [markdown]
# ### 💾 Checkpoint ZIP Export (Batch 1/4 Complete — R1 Basic)
# Saves compressed `.zip` archives of `logs_v2/` and `models_v2/` after running experiments 01–03.

# %%
import shutil
from pathlib import Path

batch_label = "checkpoint_both_batch1_basic"
base_dir = "/kaggle/working" if Path("/kaggle/working").exists() else "."

logs_zip = Path(base_dir) / f"{batch_label}_logs"
models_zip = Path(base_dir) / f"{batch_label}_models"

if Path("logs_v2").exists():
    shutil.make_archive(str(logs_zip), 'zip', 'logs_v2')
    print(f"Saved logs archive   -> {logs_zip}.zip")

if Path("models_v2").exists():
    shutil.make_archive(str(models_zip), 'zip', 'models_v2')
    print(f"Saved models archive -> {models_zip}.zip")

# %% [markdown]
# ### Experiment 04/12: R2_N1 — R2 Shaped x N1 (0.00)
# **Reward:** `shaped` | **Sensor Noise:** `0.00` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 04/12: R2_N1 (R2 Shaped x N1 (0.00))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 3 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 3 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 05/12: R2_N2 — R2 Shaped x N2 (0.02)
# **Reward:** `shaped` | **Sensor Noise:** `0.02` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 05/12: R2_N2 (R2 Shaped x N2 (0.02))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 4 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 4 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 06/12: R2_N3 — R2 Shaped x N3 (0.05)
# **Reward:** `shaped` | **Sensor Noise:** `0.05` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 06/12: R2_N3 (R2 Shaped x N3 (0.05))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 5 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 5 --max-experiments 1 --headless --resume

# %% [markdown]
# ### 💾 Checkpoint ZIP Export (Batch 2/4 Complete — R2 Shaped)
# Saves compressed `.zip` archives of `logs_v2/` and `models_v2/` after running experiments 04–06.

# %%
import shutil
from pathlib import Path

batch_label = "checkpoint_both_batch2_shaped"
base_dir = "/kaggle/working" if Path("/kaggle/working").exists() else "."

logs_zip = Path(base_dir) / f"{batch_label}_logs"
models_zip = Path(base_dir) / f"{batch_label}_models"

if Path("logs_v2").exists():
    shutil.make_archive(str(logs_zip), 'zip', 'logs_v2')
    print(f"Saved logs archive   -> {logs_zip}.zip")

if Path("models_v2").exists():
    shutil.make_archive(str(models_zip), 'zip', 'models_v2')
    print(f"Saved models archive -> {models_zip}.zip")

# %% [markdown]
# ### Experiment 07/12: R3_N1 — R3 Modified x N1 (0.00)
# **Reward:** `modified` | **Sensor Noise:** `0.00` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 07/12: R3_N1 (R3 Modified x N1 (0.00))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 6 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 6 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 08/12: R3_N2 — R3 Modified x N2 (0.02)
# **Reward:** `modified` | **Sensor Noise:** `0.02` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 08/12: R3_N2 (R3 Modified x N2 (0.02))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 7 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 7 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 09/12: R3_N3 — R3 Modified x N3 (0.05)
# **Reward:** `modified` | **Sensor Noise:** `0.05` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 09/12: R3_N3 (R3 Modified x N3 (0.05))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 8 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 8 --max-experiments 1 --headless --resume

# %% [markdown]
# ### 💾 Checkpoint ZIP Export (Batch 3/4 Complete — R3 Modified)
# Saves compressed `.zip` archives of `logs_v2/` and `models_v2/` after running experiments 07–09.

# %%
import shutil
from pathlib import Path

batch_label = "checkpoint_both_batch3_modified"
base_dir = "/kaggle/working" if Path("/kaggle/working").exists() else "."

logs_zip = Path(base_dir) / f"{batch_label}_logs"
models_zip = Path(base_dir) / f"{batch_label}_models"

if Path("logs_v2").exists():
    shutil.make_archive(str(logs_zip), 'zip', 'logs_v2')
    print(f"Saved logs archive   -> {logs_zip}.zip")

if Path("models_v2").exists():
    shutil.make_archive(str(models_zip), 'zip', 'models_v2')
    print(f"Saved models archive -> {models_zip}.zip")

# %% [markdown]
# ### Experiment 10/12: R4_N1 — R4 Tuned x N1 (0.00)
# **Reward:** `tuned` | **Sensor Noise:** `0.00` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 10/12: R4_N1 (R4 Tuned x N1 (0.00))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 9 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 9 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 11/12: R4_N2 — R4 Tuned x N2 (0.02)
# **Reward:** `tuned` | **Sensor Noise:** `0.02` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 11/12: R4_N2 (R4 Tuned x N2 (0.02))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 10 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 10 --max-experiments 1 --headless --resume

# %% [markdown]
# ### Experiment 12/12: R4_N3 — R4 Tuned x N3 (0.05)
# **Reward:** `tuned` | **Sensor Noise:** `0.05` | **Seeds:** `0, 42, 123` | **Algorithms:** `TD3 + DDPG`

# %%
# Condition 12/12: R4_N3 (R4 Tuned x N3 (0.05))
# 1. Run TD3 for this condition
# !python run_experiments.py --algo td3 --start-index 11 --max-experiments 1 --headless --resume

# 2. Run DDPG for this condition
# !python run_experiments.py --algo ddpg --start-index 11 --max-experiments 1 --headless --resume

# %% [markdown]
# ### 💾 Checkpoint ZIP Export (Batch 4/4 Complete — R4 Tuned)
# Saves compressed `.zip` archives of `logs_v2/` and `models_v2/` after running experiments 10–12.

# %%
import shutil
from pathlib import Path

batch_label = "checkpoint_both_batch4_tuned"
base_dir = "/kaggle/working" if Path("/kaggle/working").exists() else "."

logs_zip = Path(base_dir) / f"{batch_label}_logs"
models_zip = Path(base_dir) / f"{batch_label}_models"

if Path("logs_v2").exists():
    shutil.make_archive(str(logs_zip), 'zip', 'logs_v2')
    print(f"Saved logs archive   -> {logs_zip}.zip")

if Path("models_v2").exists():
    shutil.make_archive(str(models_zip), 'zip', 'models_v2')
    print(f"Saved models archive -> {models_zip}.zip")

# %% [markdown]
# ## 6. Generate Publication Figures & Visualizations

# %%
# Generate high-resolution (300 DPI PNG) and vector PDF figures
# !python plot_metrics.py --logs-dir logs_v2 --results-dir results_v2 --compare-algos

# %% [markdown]
# ## 7. Generate Aggregated Research Report & Tables

# %%
# Generate CSV tables and comprehensive analysis report
# !python generate_td3_ddpg_report.py --logs-dir logs_v2 --results-dir results_v2 --strict

# %% [markdown]
# ## 8. Export Results Archive (ZIP)

# %%
import shutil
from pathlib import Path

zip_dest = "/kaggle/working/final_results_v2" if Path("/kaggle/working").exists() else "./final_results_v2"
shutil.make_archive(zip_dest, 'zip', 'results_v2')
print(f"Results archive created successfully -> {zip_dest}.zip")
